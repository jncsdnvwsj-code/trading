# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 96
#      92 strike_prices = np.arange(75, 126, 5)
#      94 # Create Market Prices with an intentional Volatility Skew for the plot
#      95 # Assume 40% IV for OTM (low strike) and 20% for ATM/ITM
# ---> 96 market_prices = [BS_Call(S, K, T, r, vol) for K in strike_prices]
#      98 # --- CALCULATE IMPLIED VOLATILITY (Y-AXIS) ---
#      99 implied_vols = []
#
# Cell In[21], line 96, in <listcomp>(.0)
#      92 strike_prices = np.arange(75, 126, 5)
#      94 # Create Market Prices with an intentional Volatility Skew for the plot
#      95 # Assume 40% IV for OTM (low strike) and 20% for ATM/ITM
# ---> 96 market_prices = [BS_Call(S, K, T, r, vol) for K in strike_prices]
#      98 # --- CALCULATE IMPLIED VOLATILITY (Y-AXIS) ---
#      99 implied_vols = []
#
# NameError: name 'vol' is not defined
